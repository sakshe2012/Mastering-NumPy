# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5])
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1.shape  # Returns the shape of the array.
# Out:
# (5,)

# %%
arr2=np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
arr2
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
arr2.shape   # 2 row 2 column 2 matrix
# Out:
# (2, 2, 2)

# %%
arr2.ndim   # diamnesion of array
# Out:
# 3

# %%
arr1.size   #  total numbers of elemenst
# Out:
# 5

# %%
 arr2.size
# Out:
# 8

# %%
arr2.itemsize # Memory occupied by one element (in bytes)
# Out:
# 8

# %%
arr1.dtype  # datatype of array elements
# Out:
# dtype('int64')

# %%
arr1.astype('float')  # converting int data into float data of array element
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr1.itemsize
# Out:
# 8
