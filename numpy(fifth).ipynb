# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5,6])
arr2=np.array([4,5,6,7,8,9])

# %%
arr1-arr2          # element wise subtraction
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %%
 arr1* arr2   # elemetwise multilplication     (vector multiplication)
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %%
arr1* 3   # each ele is muiltipied by 3-- scalar multiplication
# Out:
# array([ 3,  6,  9, 12, 15, 18])

# %%
arr2>4  # check each elem is greter thanv4 or not
# Out:
# array([False,  True,  True,  True,  True,  True])

# %%
arr3=np.arange(6).reshape(2,3)
arr4=np.arange(6,12).reshape(3,2)

# %%
arr3.dot(arr4)
# dot poroduct
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1.dot(arr2)
# Out:
# np.int64(154)

# %%
arr4.max()  # max value in arr4
# Out:
# np.int64(11)

# %%
arr4.min()  # min vale
# Out:
# np.int64(6)

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr4.min(axis=0)   # it give min value colums wise axis=0
# Out:
# array([6, 7])

# %%
arr4.min(axis=1)  # it give min value row wise
# Out:
# array([ 6,  8, 10])

# %%
arr4.sum()
# Out:
# np.int64(51)

# %%
arr4.sum(axis=0)   # colum wise sum
# Out:
# array([24, 27])

# %%
arr4.sum(axis=1)  # row wise sum
# Out:
# array([13, 17, 21])

# %%
arr4.mean()
# Out:
# np.float64(8.5)

# %%
arr4.mean(axis=0)
# Out:
# array([8., 9.])

# %%
arr4.mean(axis=1)
# Out:
# array([ 6.5,  8.5, 10.5])

# %%
arr4.std()   # gives standard deviation of array
# Out:
# np.float64(1.707825127659933)

# %%
arr4.std(axis=0)  # colums wise SD
# Out:
# array([1.63299316, 1.63299316])

# %%
arr4.std(axis=1)  # row wise SD
# Out:
# array([0.5, 0.5, 0.5])

# %%
np.sin(arr4)  # calculates the sine value of each element in a NumPy array.
# Out:
# array([[-0.2794155 ,  0.6569866 ],
#        [ 0.98935825,  0.41211849],
#        [-0.54402111, -0.99999021]])

# %%
np.median(arr4)
# Out:
# np.float64(8.5)

# %%
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])

# %%
np.log(arr4)
# Out:
# array([[1.79175947, 1.94591015],
#        [2.07944154, 2.19722458],
#        [2.30258509, 2.39789527]])

# %%
np.tan(arr4)
# Out:
# array([[  -0.29100619,    0.87144798],
#        [  -6.79971146,   -0.45231566],
#        [   0.64836083, -225.95084645]])

# %%
np.cos(arr4)
# Out:
# array([[ 0.96017029,  0.75390225],
#        [-0.14550003, -0.91113026],
#        [-0.83907153,  0.0044257 ]])
