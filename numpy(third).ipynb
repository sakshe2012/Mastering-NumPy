# %%
import numpy as np

# %%
lista= range(100)  # it will cotain 0 to 99 element

# %%
arr1 =np.arange(100)

# %%
import sys

# %%
print(sys.getsizeof(87)*len(lista))
# Out:
# 2800

# %%
print(arr1.itemsize*arr1.size)
# Out:
# 800

# %%
import time

# %%
x=range(10000000)
y=range(10000000,2000000)

# %%
start_time=time.time()

# %%
c=[(x,y) for x,y in zip(x,y)]  # zip= add elements of both list

# %%
print(time.time()- start_time)
# Out:
# 0.930978536605835

# %%
a= np.arange(10000000)
b=np.arange(10000000,20000000)

# %%
start_timr=time.time()

# %%
c=a+b

# %%
print(time.time()-start_time)
# Out:
# 9.030925989151001
